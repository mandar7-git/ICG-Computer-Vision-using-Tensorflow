# %%
import matplotlib.pyplot as plt
import numpy as np
from sklearn import datasets
from sklearn.model_selection import train_test_split

# Generate the data
X, y = datasets.make_regression(n_samples=100, n_features=5, noise=20, random_state=4)

# Split the data
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.2, random_state=1234)

# %%
import matplotlib.pyplot as plt
plt.scatter(X_train[:,0],y_train)
plt.show()

# %%
import matplotlib.pyplot as plt
plt.scatter(X_train[:,1],y_train)
plt.show()

# %%
import matplotlib.pyplot as plt
plt.scatter(X_train[:,2],y_train)
plt.show()

# %%
import matplotlib.pyplot as plt
plt.scatter(X_train[:,3],y_train)
plt.show()

# %%
import matplotlib.pyplot as plt
plt.scatter(X_train[:,4],y_train)
plt.show()

# %%
import numpy as np

class LinearRegression:

    # The __init__ is called when we make any object of our class. Here, you are to specify the default values for 
    # Learning Rate, Number of Iterations, Weights and Biases. It doesn't return anything.
    # Hint: Google what a `self pointer` is and figure out how it can be used here
    def __init__(self, learning_rate=0.001, n_iters=1000):
        # Your code here
        self.n_iters=n_iters
        self.learning_rate=learning_rate
        self.weight = np.full(X.shape[1],0)
        self.b=0.0


    # The following function would be the heart of the model. This is where the training would happen. 
    # You're supposed to iterate and keep on updating the weights and biases according to the steps of Gradient Descent.
    
    def fit(self, X, y):
        
        for a in range(0,self.n_iters):
          z = np.dot(X,self.weight)+ self.b
          error_w = -2/y.size*np.dot(X.T,(y-z))
          error_b = -2/y.size*np.sum((y-z))
          costfn= 1/y.size*np.sum(np.square(y-z))
          self.weight = self.weight-self.learning_rate*error_w
          self.b =self.b- self.learning_rate*error_b

        
    def predict(self, X):
        return np.dot(X,self.weight) + self.b

# %%
# Now, we make an object of our custom class.
regressor = LinearRegression() # You may pass the custom parameters or let the default values take it ahead

# Call the fit method on the object to train (pass appropriate part of dataset)
regressor.fit(X_train, y_train)

# Now, let's see our what our model predicts
predictions = regressor.predict(X_test) # pass appropriate part of dataset

# %%
  def mean_squared_error(yt, y_predection):
       # return the mean squared error
 return np.sum(np.dot(yt-y_predection,yt-y_predection)/yt
# Out:
#   Input In [211]
#
#     ^
# SyntaxError: unexpected EOF while parsing

# %%
    
   predictions = regressor.predict(X_test)
   def r2_score(yt, y_predection):
      sum_sq_regression = np.sum(np.dot(yt-y_predection,yt-y_predection))
      total_sum_sq = np.sum(np.dot(yt-np.mean(yt),yt-np.mean(yt)))
      return sum_sq_regression/total_sum_sq
    
mse = mean_squared_error(y_test,predictions) # Pass appropriate parts of dataset
print("MSE:", mse)

acc = r2_score(y_test,predictions) # Pass appropriate parts of dataset
print("Accuracy:", acc)
# Out:
# MSE: [  56.96385133 -103.25450904  160.77056829 -115.12513474 -322.11044187
#  -284.41130314  769.22641357  360.36625954  -91.2662928    76.54733025
#   253.5161727    87.3934027   538.71993213  170.13918318  210.58363428
#   172.66038501   67.52432962  276.18288822  168.79307679 -172.88833387]
# Accuracy: 0.062342818277065844
