# %% [markdown]
# # Assigment 2: Deep Learning

# %% [markdown]
# ## Generate Dataset
#
# This is the same code from Assignment 1

# %%
from sklearn import datasets
from sklearn.model_selection import train_test_split

# Generate the data
X, y = datasets.make_regression(n_samples=100, n_features=5, noise=5, random_state=4)

# Split the data
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.2, random_state=1234)

# %%
X_train.shape
# Out:
# (80, 5)

# %% [markdown]
# ## Visualize Dataset
# This is the same code from Assignment 1

# %%
import matplotlib.pyplot as plt
fig, axs = plt.subplots(5,figsize=(4,20))
fig.suptitle('Visualising Data')
for i in range(5):
  axs[i].scatter(X[:,i],y)
# Your code here

# %% [markdown]
# ## Model Definition
#
# Using TensorFlow, build a model with the following definition:
# > Input of shape 5 \\
# > Dense of shape 5 \\
# > Dense of shape 5 \\
# > Dense of shape 1 \\
#
# Use Mean Square Error Loss and Stochaistic Gradient Descent (SGD) Optimizer
#
# Use Gradient Decay with appropriate parameters

# %%
import tensorflow as tf

# inputs = tf.keras.Input(5)
# x = tf.keras.layers.Dense(5)(inputs)
# x = tf.keras.layers.Dense(5,activation='relu')(x)
# outputs = tf.keras.layers.Dense(1)(x)
# model = tf.keras.Model(inputs=inputs, outputs=outputs)

# Alternate
# In sequential it is not needed to have Input Size mentioned
model=tf.keras.Sequential([
    tf.keras.layers.Dense(5,activation='relu'),
    tf.keras.layers.Dense(5,activation='relu'),
    tf.keras.layers.Dense(1)
])

# %%
# model.summary() # Call this if using first method

# %%
model.compile(optimizer=tf.keras.optimizers.SGD(learning_rate=0.001),loss=tf.keras.losses.MeanSquaredError(),metrics=[tf.keras.losses.MeanSquaredError()])

# %%
history=model.fit(X_train,y_train,validation_split=0.1,epochs=50)
# Out:
# Epoch 1/50
# 3/3 [==============================] - 1s 164ms/step - loss: 12151.7637 - mean_squared_error: 13688.9961 - val_loss: 5728.4336 - val_mean_squared_error: 5728.4336
# Epoch 2/50
# 3/3 [==============================] - 0s 23ms/step - loss: 11798.6318 - mean_squared_error: 11793.2139 - val_loss: 4623.6997 - val_mean_squared_error: 4623.6997
# Epoch 3/50
# 3/3 [==============================] - 0s 49ms/step - loss: 10025.9268 - mean_squared_error: 7975.1328 - val_loss: 1722.9556 - val_mean_squared_error: 1722.9556
# Epoch 4/50
# 3/3 [==============================] - 0s 20ms/step - loss: 6316.1929 - mean_squared_error: 5920.7402 - val_loss: 1942.3257 - val_mean_squared_error: 1942.3257
# Epoch 5/50
# 3/3 [==============================] - 0s 30ms/step - loss: 6526.5825 - mean_squared_error: 8165.7466 - val_loss: 1590.0300 - val_mean_squared_error: 1590.0300
# Epoch 6/50
# ...

# %% [markdown]
# ## Plot Loss
#
# Using matplotlib visualise how the loss (both validation and training) is changing, use this information to retrain the model with appropriate parameters.<br>We ideally want the loss to be constant over the last few iterations.

# %%
plt.plot(history.history['loss'])
plt.plot(history.history['val_loss'])
plt.title('model loss')
plt.ylabel('loss')
plt.xlabel('epoch')
plt.legend(['train', 'validation'], loc='upper left')
plt.show()

# %% [markdown]
# ## Evaluation Metrics
# Use the R2 Score function implemented in the first assignment to evaluate the performance of the model.

# %%
# Insert the function for R2 Score
predictions=model.predict(X_test)
from sklearn.metrics import r2_score
accu = r2_score(y_test,predictions) # Pass appropriate parts of dataset
print("Accuracy:", accu)
# Out:
# Accuracy: 0.19732762160930106

# %% [markdown]
# ## Your own custom model
# Build a custom model of your own choice.<br>
# Describe it in detail in Markdown/Latex in the cell below.<br>
# Visualise the loss, as before.

# %% [markdown]
# Your text here

# %%
# Your code here

# %%
# inputs = tf.keras.Input(5)
# x = tf.keras.layers.Dense(5)(inputs)
# x = tf.keras.layers.Dense(5,activation='relu')(x)
# outputs = tf.keras.layers.Dense(1)(x)
# modelCustom = tf.keras.Model(inputs=inputs, outputs=outputs)
# modelCustom.summary()

# %%
# modelCustom.compile(optimizer=tf.keras.optimizers.SGD(learning_rate=0.001),loss=tf.keras.losses.MeanSquaredError(),metrics=[tf.keras.losses.MeanSquaredError()])

# %%
# historyCustom=model.fit(X_train,y_train,validation_split=0.1,epochs=50)

# %%
# plt.plot(historyCustom.history['loss'])
# plt.plot(historyCustom.history['val_loss'])
# plt.title('model loss')
# plt.ylabel('loss')
# plt.xlabel('epoch')
# plt.legend(['train', 'validation'], loc='upper left')
# plt.show()

# %%
# predictions=modelCustom.predict(X_test)
# from sklearn.metrics import r2_score
# accu = r2_score(y_test,predictions) # Pass appropriate parts of dataset
# print("Accuracy:", accu)
